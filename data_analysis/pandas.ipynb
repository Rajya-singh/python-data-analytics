# %% [markdown]
# ## loding the data

# %%
import pandas as pd

# %%
df=pd.read_excel('data.xlsx.xlsx')

# %% [markdown]
# ## loking and exploring the data

# %%
df.head() # top 5 rows max 30 rows look
# Out:
#   Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 0    Argentina              2                    Adidas       GK
# 1    Argentina              2                    Adidas       GK
# 2    Argentina              2                    Adidas       GK
# 3    Argentina              2                    Adidas       DF
# 4    Argentina              2                    Adidas       DF
#
#    National Team Jersey Number           Player DOB        Club   \
# 0                         23.0  1992-09-02 00:00:00  Aston Villa
# 1                          1.0  1986-10-16 00:00:00        River
# 2                         12.0  1992-05-20 00:00:00   Villarreal
# 3                         19.0  1988-02-12 00:00:00      Benfica
# 4                          8.0  1991-10-28 00:00:00      Sevilla
#
#         Player Name   Appearances Goals Scored  Assists Provided   \
# 0  Emiliano Martinez            7             0                 0
# 1      Franco Armani            0             -                 -
# 2     Geronimo Rulli            0             -                 -
# 3   Nicolas Otamendi            7             0                 1
# 4       Marcos Acuna            6             0                 0
#
#   Dribbles per 90 Interceptions per 90 Tackles per 90 Total Duels Won per 90  \
# 0               0                    0              0                   0.65
# 1               -                    -              -                      -
# 2               -                    -              -                      -
# 3            0.33                 1.17            1.3                   7.17
# 4            1.45                 0.48            2.9                   7.97
#
#   Save Percentage Clean Sheets Brand Sponsor/Brand Used
# 0          0.4667         0.43                   Adidas
# 1               -            -                     Nike
# 2               -            -                   Adidas
# 3               -            -                     Nike
# 4               -            -                     Nike

# %%
df.tail() # bottom 5 rows
# Out:
#     Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 809       Canada             53                      Nike       FW
# 810       Canada             53                      Nike       FW
# 811       Canada             53                      Nike       FW
# 812       Canada             53                      Nike       FW
# 813       Canada             53                      Nike       FW
#
#      National Team Jersey Number           Player DOB          Club   \
# 809                         17.0  1995-04-17 00:00:00    Club Brugge
# 810                         19.0  2000-11-02 00:00:00  Bayern Munich
# 811                         20.0  2000-01-14 00:00:00          Lille
# 812                         23.0  1999-09-27 00:00:00          Basel
# 813                         12.0  1998-09-21 00:00:00         Troyes
#
#         Player Name   Appearances Goals Scored  Assists Provided   \
# 809       Cyle Larin            3             0                 0
# 810  Alphonso Davies            3             1                 0
# 811   Jonathan David            3             0                 0
# 812      Liam Millar            1             0                 0
# 813         Ike Ugbo          N.A           N.A               N.A
#
#     Dribbles per 90 Interceptions per 90 Tackles per 90  \
# 809            1.33                    0              0
# 810               6                    1           0.67
# 811            1.41                    0           0.47
# 812               0                    0              0
# 813             N.A                  N.A            N.A
#
#     Total Duels Won per 90 Save Percentage Clean Sheets  \
# 809                   1.95               -            -
# 810                   6.67               -            -
# 811                   1.88               -            -
# 812                      0               -            -
# 813                    N.A               -            -
#
#     Brand Sponsor/Brand Used
# 809                     Nike
# 810                     Nike
# 811                   Adidas
# 812                   Adidas
# 813                     Nike

# %%
df.loc[515:535] # named location wise data, last index include
# Out:
#     Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 515      Mexico              15                    Adidas       DF
# 516      Mexico              15                    Adidas       DF
# 517      Mexico              15                    Adidas       DF
# 518      Mexico              15                    Adidas       DF
# 519      Mexico              15                    Adidas       DF
# 520      Mexico              15                    Adidas       DF
# 521      Mexico              15                    Adidas       MF
# 522      Mexico              15                    Adidas       MF
# 523      Mexico              15                    Adidas       MF
# 524      Mexico              15                    Adidas       MF
# 525      Mexico              15                    Adidas       MF
# 526      Mexico              15                    Adidas       MF
# 527      Mexico              15                    Adidas       MF
# 528      Mexico              15                    Adidas       MF
# 529      Mexico              15                    Adidas       MF
# 530      Mexico              15                    Adidas       MF
# 531      Mexico              15                    Adidas       MF
# 532      Mexico              15                    Adidas       FW
# 533      Mexico              15                    Adidas       FW
# 534      Mexico              15                    Adidas       FW
# 535      Mexico              15                    Adidas       FW
#
#      National Team Jersey Number           Player DOB           Club   \
# 515                          2.0  1991-08-29 00:00:00         America
# 516                          3.0  1997-02-24 00:00:00       Monterrey
# 517                         19.0  1997-12-10 00:00:00            Ajax
# 518                          6.0  1998-09-07 00:00:00            Genk
# 519                         26.0  1999-01-15 00:00:00         Pachuca
# 520                          5.0  1998-10-22 00:00:00       Cremonese
# 521                         18.0  1986-09-28 00:00:00      Real Betis
# 522                         16.0  1990-04-19 00:00:00  Houston Dynamo
# 523                          4.0  1997-10-24 00:00:00            Ajax
# 524                         17.0  1996-03-24 00:00:00      AEK Athens
# 525                         21.0  1997-08-21 00:00:00       Cruz Azul
# 526                         14.0  1995-06-15 00:00:00             PSV
# 527                          8.0  1997-01-03 00:00:00       Cruz Azul
# 528                         25.0  1998-09-07 00:00:00     Guadalajara
# 529                          7.0  1995-06-05 00:00:00       Monterrey
# 530                         10.0  1997-11-25 00:00:00     Guadalajara
# 531                         24.0  1996-01-15 00:00:00         Pachuca
# 532                          9.0  1991-05-05 00:00:00          Wolves
# 533                         22.0  1995-07-30 00:00:00          Napoli
# 534                         20.0  1992-11-18 00:00:00         America
# 535                         11.0  1991-03-05 00:00:00       Monterrey
#
#            Player Name   Appearances Goals Scored  Assists Provided   \
# 515       Nestor Araujo            1             0                 0
# 516        Cesar Montes            3             0                 1
# 517       Jorge Sanchez            2             0                 0
# 518     Gerardo Arteaga          N.A           N.A               N.A
# 519       Kevin Alvarez            2             0                 0
# 520       Johan Vasquez          N.A           N.A               N.A
# 521     Andres Guardado            1             0                 0
# 522      Hector Herrera            3             0                 0
# 523       Edson Alvarez            2             0                 0
# 524      Orbelin Pineda            1             0                 0
# 525        Uriel Antuna            3             0                 0
# 526     Erick Gutierrez            1             0                 0
# 527    Carlos Rodriguez            2             0                 0
# 528    Roberto Alvarado            1             0                 0
# 529           Luis Romo          N.A           N.A               N.A
# 530         Alexis Vega            3             0                 0
# 531         Luis Chavez            3             1                 0
# 532        Raul Jimenez            3             0                 0
# 533      Hirving Lozano            3             0                 0
# 534        Henry Martin            2             1                 0
# 535  Rogelio Funes Mori            1             0                 0
#
#     Dribbles per 90 Interceptions per 90 Tackles per 90  \
# 515               0                    3              1
# 516            0.67                 0.67              2
# 517            2.56                 1.02           0.51
# 518             N.A                  N.A            N.A
# 519            3.86                 1.29           1.29
# 520             N.A                  N.A            N.A
# 521               0                    0           8.57
# 522               0                 0.33           0.67
# 523            0.51                 2.05           1.02
# 524            1.17                    0           4.68
# 525               0                    0           4.86
# 526               0                 3.75           1.88
# 527               2                    0              0
# 528               1                    0              0
# 529             N.A                  N.A            N.A
# 530            1.38                 0.46              0
# 531            1.33                    0           0.33
# 532               0                 1.61              0
# 533            2.49                    0           2.49
# 534               0                 1.82           0.61
# 535               0                    0            N.A
#
#     Total Duels Won per 90 Save Percentage Clean Sheets  \
# 515                      1               -            -
# 516                   7.33               -            -
# 517                    4.7               -            -
# 518                    N.A               -            -
# 519                   3.86               -            -
# 520                    N.A               -            -
# 521                   8.57               -            -
# 522                      5               -            -
# 523                  13.29               -            -
# 524                   9.35               -            -
# 525                   6.08               -            -
# 526                    N.A               -            -
# 527                   8.44               -            -
# 528                  10.58               -            -
# 529                    N.A               -            -
# 530                   4.13               -            -
# 531                      7               -            -
# 532                  11.25               -            -
# 533                   8.54               -            -
# 534                   6.08               -            -
# 535                    N.A               -            -
#
#     Brand Sponsor/Brand Used
# 515                     Nike
# 516                   Adidas
# 517                     Nike
# 518                     Nike
# 519                   Adidas
# 520                     Nike
# 521                   Adidas
# 522                     Nike
# 523                   Adidas
# 524                   Adidas
# 525                     Nike
# 526                   Adidas
# 527                     Nike
# 528                     Nike
# 529                   Adidas
# 530                     Nike
# 531                     Nike
# 532                     Nike
# 533                     Nike
# 534                   Adidas
# 535                     Puma

# %%
df.iloc[10:15] # indexed location,last index is not included
# Out:
#    Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 10    Argentina              2                    Adidas       DF
# 11    Argentina              2                    Adidas       DF
# 12    Argentina              2                    Adidas       MF
# 13    Argentina              2                    Adidas       MF
# 14    Argentina              2                    Adidas       MF
#
#     National Team Jersey Number           Player DOB              Club   \
# 10                         13.0  1998-04-27 00:00:00          Tottenham
# 11                         25.0  1998-01-18 00:00:00  Manchester United
# 12                          5.0  1994-06-29 00:00:00           Juventus
# 13                          7.0  1994-05-24 00:00:00    Atletico Madrid
# 14                         18.0  1994-04-12 00:00:00         Real Betis
#
#          Player Name   Appearances Goals Scored  Assists Provided   \
# 10    Cristian Romero            7             0                 0
# 11  Lisandro Martinez            5             0                 0
# 12    Leandro Paredes            5             0                 0
# 13    Rodrigo De Paul            7             0                 0
# 14    Guido Rodriguez            1             0                 0
#
#    Dribbles per 90 Interceptions per 90 Tackles per 90 Total Duels Won per 90  \
# 10            0.16                 0.49           0.82                   5.09
# 11             0.3                  0.9            1.5                   4.19
# 12             0.4                 1.21           4.02                   9.24
# 13             0.6                 1.05           1.79                   4.64
# 14               0                    0           3.16                   6.32
#
#    Save Percentage Clean Sheets Brand Sponsor/Brand Used
# 10               -            -                     Nike
# 11               -            -                   Adidas
# 12               -            -                     Nike
# 13               -            -                   Adidas
# 14               -            -                   Adidas

# %% [markdown]
# ## column wise data type and non-null value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nationality                  814 non-null    object
#  1   FIFA Ranking                 814 non-null    int64
#  2   National Team Kit Sponsor    813 non-null    object
#  3   Position                     814 non-null    object
#  4   National Team Jersey Number  813 non-null    float64
#  5   Player DOB                   814 non-null    object
#  6   Club                         814 non-null    object
#  7   Player Name                  814 non-null    object
#  8    Appearances                 814 non-null    object
#  9   Goals Scored                 813 non-null    object
#  10  Assists Provided             813 non-null    object
#  11  Dribbles per 90              813 non-null    object
#  12  Interceptions per 90         813 non-null    object
#  13  Tackles per 90               813 non-null    object
#  14  Total Duels Won per 90       813 non-null    object
#  15  Save Percentage              812 non-null    object
#  16  Clean Sheets                 814 non-null    object
#  17  Brand Sponsor/Brand Used     813 non-null    object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 114.6+ KB

# %% [markdown]
# ## summary of data statistically-numerical value

# %%
df.describe()
# Out:
#        FIFA Ranking   National Team Jersey Number
# count     814.000000                   813.000000
# mean       21.713759                    13.507995
# std        16.159655                     7.523788
# min         1.000000                     1.000000
# 25%         9.000000                     7.000000
# 50%        18.000000                    14.000000
# 75%        29.000000                    20.000000
# max        60.000000                    26.000000

# %%
## summary of data statistically-textual colmn

# %%
df.describe(include='object')
# Out:
#        Nationality  National Team Kit Sponsor Position           Player DOB  \
# count           814                       813      814                  814
# unique           32                        10        4                  749
# top       Argentina                      Nike       DF  1994-06-15 00:00:00
# freq             26                       331      262                    3
#
#             Club        Player Name    Appearances  Goals Scored   \
# count         814                814           814            813
# unique        319                814            11             10
# top     Barcelona  Emiliano Martinez             3              0
# freq           16                  1           193            469
#
#         Assists Provided   Dribbles per 90  Interceptions per 90  \
# count                 813              813                   813
# unique                  7              205                   162
# top                     0                0                     0
# freq                  498              206                   216
#
#        Tackles per 90 Total Duels Won per 90 Save Percentage Clean Sheets  \
# count             813                    813             812          814
# unique            230                    360              29           14
# top               N.A                    N.A               -            -
# freq              176                    202             761          763
#
#        Brand Sponsor/Brand Used
# count                       813
# unique                       15
# top                        Nike
# freq                        424

# %% [markdown]
# ## single column selection-series selection-dictionary like

# %%
df['Position']
df['Nationality ']
# Out:
# 0      Argentina
# 1      Argentina
# 2      Argentina
# 3      Argentina
# 4      Argentina
#          ...
# 809       Canada
# 810       Canada
# 811       Canada
# 812       Canada
# 813       Canada
# Name: Nationality , Length: 814, dtype: object

# %% [markdown]
# ## single column selection-dataframe selction-dot notation

# %%
df.Position # but if there are space in the column name, this won't work
# Out:
# 0      GK
# 1      GK
# 2      GK
# 3      DF
# 4      DF
#        ..
# 809    FW
# 810    FW
# 811    FW
# 812    FW
# 813    FW
# Name: Position, Length: 814, dtype: object

# %% [markdown]
# ## get column names

# %%
df.columns # of df.column.tolist()
# Out:
# Index(['Nationality ', 'FIFA Ranking ', 'National Team Kit Sponsor',
#        'Position', 'National Team Jersey Number', 'Player DOB', 'Club ',
#        'Player Name ', ' Appearances', 'Goals Scored ', 'Assists Provided ',
#        'Dribbles per 90', 'Interceptions per 90', 'Tackles per 90',
#        'Total Duels Won per 90', 'Save Percentage', 'Clean Sheets',
#        'Brand Sponsor/Brand Used'],
#       dtype='object')

# %% [markdown]
# ## multiple column selection-dataframe selection-list of columns

# %%
df[['Position','Player Name ']] # dataframe
# Out:
#     Position       Player Name
# 0         GK  Emiliano Martinez
# 1         GK      Franco Armani
# 2         GK     Geronimo Rulli
# 3         DF   Nicolas Otamendi
# 4         DF       Marcos Acuna
# ..       ...                ...
# 809       FW         Cyle Larin
# 810       FW    Alphonso Davies
# 811       FW     Jonathan David
# 812       FW        Liam Millar
# 813       FW           Ike Ugbo
#
# [814 rows x 2 columns]

# %% [markdown]
# ## fixing the column names

# %%
list(map(lambda col: col.strip().lower(),df.columns.tolist())) # test run
# Out:
# ['nationality',
#  'fifa ranking',
#  'national team kit sponsor',
#  'position',
#  'national team jersey number',
#  'player dob',
#  'club',
#  'player name',
#  'appearances',
#  'goals scored',
#  'assists provided',
#  'dribbles per 90',
#  'interceptions per 90',
#  'tackles per 90',
#  'total duels won per 90',
#  'save percentage',
#  'clean sheets',
#  'brand sponsor/brand used']

# %%
df.columns=list(map(lambda col: col.strip().lower(),df.columns.tolist())) #strip

# %%
df.columns.tolist()
# Out:
# ['nationality',
#  'fifa ranking',
#  'national team kit sponsor',
#  'position',
#  'national team jersey number',
#  'player dob',
#  'club',
#  'player name',
#  'appearances',
#  'goals scored',
#  'assists provided',
#  'dribbles per 90',
#  'interceptions per 90',
#  'tackles per 90',
#  'total duels won per 90',
#  'save percentage',
#  'clean sheets',
#  'brand sponsor/brand used']

# %% [markdown]
# ## replace function to fix column data

# %%
df['goals scored']=df['goals scored'].replace('-',0,)

# %% [markdown]
# ## value_count()-frequency of unique values in a column

# %%
df['goals scored'].value_counts()
# Out:
# goals scored
# 0      550
# N.A    147
# 1       86
# 2       18
# 3        7
# 4        2
# 7        1
# 8        1
# N,A      1
# Name: count, dtype: int64

# %%
import numpy as np

# %%
df['goals scored']=df['goals scored'].replace('N.A',np.nan)
df['goals scored']=df['goals scored'].replace('N.A',np.nan)

# %%
df['goals scored'].value_counts()
# Out:
# goals scored
# 0      550
# 1       86
# 2       18
# 3        7
# 4        2
# 7        1
# 8        1
# N,A      1
# Name: count, dtype: int64

# %%
df['goals scored'].value_counts().plot(
    kind='bar',
    title='Goals Scored')
# Out:
# <Axes: title={'center': 'Goals Scored'}, xlabel='goals scored'>

# %%
df.columns
# Out:
# Index(['nationality', 'fifa ranking', 'national team kit sponsor', 'position',
#        'national team jersey number', 'player dob', 'club', 'player name',
#        'appearances', 'goals scored', 'assists provided', 'dribbles per 90',
#        'interceptions per 90', 'tackles per 90', 'total duels won per 90',
#        'save percentage', 'clean sheets', 'brand sponsor/brand used'],
#       dtype='object')

# %%
df['goals scored']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#       ...
# 809      0
# 810      1
# 811      0
# 812      0
# 813    NaN
# Name: goals scored, Length: 814, dtype: object

# %% [markdown]
# ## sorting

# %%
df=df.sort_values(by='goals scored', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 df=df.sort_values(by='goals scored', ascending=False)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\frame.py:6955, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6952     if isinstance(ascending, (tuple, list)):
#    6953         ascending = ascending[0]
# -> 6955     indexer = nargsort(
#    6956         k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6957     )
#    6958 else:
#    6959     if inplace:
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\sorting.py:483, in nargsort(items, kind, ascending, na_position, key, mask)
#     481     non_nans = non_nans[::-1]
#     482     non_nan_idx = non_nan_idx[::-1]
# --> 483 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     484 if not ascending:
#     485     indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# ## now make a chart long version

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(10,6))
bars=plt.bar(x='player name',height='goals scored',color='pink',hatch='//',edgecolor='white',width=0.5,data=df.head(10))
# name of country on each bar
for bar,cation in zip(bars,df.head(10).nationality):
    yval=bar.get_height()
    plt.text(x=bar.get_x(),
             y=yval+.1,
             s=nation,
             fontdict={'size':6},
            )
plt.xticks(rotation=45)
plt.title('Top 10 Goals scorers in 2022')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.subplots(figsize=(10,6))
# ----> 3 bars=plt.bar(x='player name',height='goals scored',color='pink',hatch='//',edgecolor='white',width=0.5,data=df.head(10))
#       4 # name of country on each bar
#       5 for bar,cation in zip(bars,df.head(10).nationality):
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## short version

# %%
df.head(15)[::-1].plot(kind='barh',x='player  name',y='goals scored')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player  name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.head(15)[::-1].plot(kind='barh',x='player  name',y='goals scored')
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\plotting\_core.py:996, in PlotAccessor.__call__(self, *args, **kwargs)
#     994 if is_integer(x) and not data.columns._holds_integer():
#     995     x = data_cols[x]
# --> 996 elif not isinstance(data[x], ABCSeries):
#     997     raise ValueError("x must be a label or position")
#     998 data = data.set_index(x)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'player  name'

# %% [markdown]
# ## goals xcores and assists

# %%
df.head(15)[::-1].plot(kind='barh',x='player name',
                       y=['goals scored','assists proided'],
                        )
# Out:
#   Cell In[28], line 2
#     y=[goals scored',assists proided'],
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.head(15)[::-1].plot(kind='barh',x='player name',
                       y=['foals scored','assists provided']
                       stacked=True)
# Out:
#   Cell In[29], line 2
#     y=['foals scored','assists provided']
#       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# club with most plyers
df['club'].value_counts().head(10).plot(kind='pie',
                                        color='crange',
                                        autopct='%.1f%%', # autoct = ->automatic percentage and another % for percentage
                                        startangle=90,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # club with most plyers
# ----> 2 df['club'].value_counts().head(10).plot(kind='pie',
#       3                                         color='crange',
#       4                                         autopct='%.1f%%', # autoct = ->automatic percentage and another % for percentage
#       5                                         startangle=90,)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:453, in MPLPlot.generate(self)
#     451 self._compute_plot_data()
#     452 self._setup_subplots()
# --> 453 self._make_plot()
#     454 self._add_table()
#     455 self._make_legend()
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1866, in PiePlot._make_plot(self)
#    1864 else:
#    1865     blabels = None
# -> 1866 results = ax.pie(y, labels=blabels, **kwds)
#    1868 if kwds.get("autopct", None) is not None:
#    1869     patches, texts, autotexts = results
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.pie() got an unexpected keyword argument 'color'

# %%
# culb with most goals 
bars=df.groupby('club')['goals scored'].sum().sort_values(
    ascending=False).head(10).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # culb with most goals
# ----> 2 bars=df.groupby('club')['goals scored'].sum().sort_values(
#       3     ascending=False).head(10).plot(kind='bar')
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1839, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1830 @final
#    1831 def _agg_general(
#    1832     self,
#    (...)
#    1837     npfunc: Callable,
#    1838 ):
# -> 1839     result = self._cython_agg_general(
#    1840         how=alias,
#    1841         alt=npfunc,
#    1842         numeric_only=numeric_only,
#    1843         min_count=min_count,
#    1844     )
#    1845     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\internals\base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1905, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1903 def array_func(values: ArrayLike) -> ArrayLike:
#    1904     try:
# -> 1905         result = self.grouper._cython_operation(
#    1906             "aggregate",
#    1907             values,
#    1908             how,
#    1909             axis=data.ndim - 1,
#    1910             min_count=min_count,
#    1911             **kwargs,
#    1912         )
#    1913     except NotImplementedError:
#    1914         # generally if we have numeric_only=False
#    1915         # and non-applicable functions
#    1916         # try to python agg
#    1917         # TODO: shouldn't min_count matter?
#    1918         # TODO: avoid special casing SparseArray here
#    1919         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:324, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     322 if result_mask is not None:
#     323     result_mask = result_mask[None, :]
# --> 324 res = self._call_cython_op(
#     325     values2d,
#     326     min_count=min_count,
#     327     ngroups=ngroups,
#     328     comp_ids=comp_ids,
#     329     mask=mask,
#     330     result_mask=result_mask,
#     331     **kwargs,
#     332 )
#     333 if res.shape[0] == 1:
#     334     return res[0]
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:404, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     402 counts = np.zeros(ngroups, dtype=np.int64)
#     403 if self.how in ["min", "max", "mean", "last", "first", "sum"]:
# --> 404     func(
#     405         out=result,
#     406         counts=counts,
#     407         values=values,
#     408         labels=comp_ids,
#     409         min_count=min_count,
#     410         mask=mask,
#     411         result_mask=result_mask,
#     412         is_datetimelike=is_datetimelike,
#     413     )
#     414 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     415     if self.how in ["std", "sem"]:
#
# File groupby.pyx:718, in pandas._libs.groupby.group_sum()
#
# TypeError: can only concatenate str (not "int") to str

# %%
# culb with most goals
bars=df.groupby('club')['goals scored'].sum().sort_values(
    ascending=False).head(10).plot(kind='bar')
# highlight the 1st place
bars.patches[0].set_color('orange')
# goals scored on each bar
for bar in bars.patches:
    yval=bar.get_hight()
    plt.text(x=bar.get_x()+bar.get_width()/2,
             y=1,
             s=f'{int(yval)}',
             ha='ccenter',
             fontdict={'size':12,'color':'white','weight':'bold'},
             rotation=9,
             )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # culb with most goals
# ----> 2 bars=df.groupby('club')['goals scored'].sum().sort_values(
#       3     ascending=False).head(10).plot(kind='bar')
#       4 # highlight the 1st place
#       5 bars.patches[0].set_color('orange')
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1839, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1830 @final
#    1831 def _agg_general(
#    1832     self,
#    (...)
#    1837     npfunc: Callable,
#    1838 ):
# -> 1839     result = self._cython_agg_general(
#    1840         how=alias,
#    1841         alt=npfunc,
#    1842         numeric_only=numeric_only,
#    1843         min_count=min_count,
#    1844     )
#    1845     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\internals\base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1905, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1903 def array_func(values: ArrayLike) -> ArrayLike:
#    1904     try:
# -> 1905         result = self.grouper._cython_operation(
#    1906             "aggregate",
#    1907             values,
#    1908             how,
#    1909             axis=data.ndim - 1,
#    1910             min_count=min_count,
#    1911             **kwargs,
#    1912         )
#    1913     except NotImplementedError:
#    1914         # generally if we have numeric_only=False
#    1915         # and non-applicable functions
#    1916         # try to python agg
#    1917         # TODO: shouldn't min_count matter?
#    1918         # TODO: avoid special casing SparseArray here
#    1919         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:324, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     322 if result_mask is not None:
#     323     result_mask = result_mask[None, :]
# --> 324 res = self._call_cython_op(
#     325     values2d,
#     326     min_count=min_count,
#     327     ngroups=ngroups,
#     328     comp_ids=comp_ids,
#     329     mask=mask,
#     330     result_mask=result_mask,
#     331     **kwargs,
#     332 )
#     333 if res.shape[0] == 1:
#     334     return res[0]
#
# File c:\Users\Lenovo\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:404, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     402 counts = np.zeros(ngroups, dtype=np.int64)
#     403 if self.how in ["min", "max", "mean", "last", "first", "sum"]:
# --> 404     func(
#     405         out=result,
#     406         counts=counts,
#     407         values=values,
#     408         labels=comp_ids,
#     409         min_count=min_count,
#     410         mask=mask,
#     411         result_mask=result_mask,
#     412         is_datetimelike=is_datetimelike,
#     413     )
#     414 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     415     if self.how in ["std", "sem"]:
#
# File groupby.pyx:718, in pandas._libs.groupby.group_sum()
#
# TypeError: can only concatenate str (not "int") to str
